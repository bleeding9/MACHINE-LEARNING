# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH_TO_FILE: str = '/content/StudentPerformanceFactors.csv'
df = pd.read_csv(PATH_TO_FILE)

# %%
df #вывод
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.head() #первые 5 строк
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
# Статистический разбор
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %% [markdown]
# # **Определение типов переменных**

# %%
print(df.dtypes)
# Список столбцов и их типов данных
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# Числовые переменные (типы int64):
# Hours Studied, Attendance, Sleep_Hours, Previous_Scores, Tutoring_Sessions, Physical_Activity, Exam_Score
#
# Категориальные переменные (тип object):
# Parental_Involvement, Access_to_Resources, Extracurricular_Activities, Motivation_level, Internet_Access, Family_Income, Teacher_Quality, School_Type, Peer_Influence, Learning_Disabilities, Parental_Education_level, Distance_from_Home, Gender

# %% [markdown]
# ### Статистический разбор данных

# %% [markdown]
# 1. Посчитайте количество уникальных значений для каждой переменно

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# Hours_Studied: 41 уникальных значений
# Attendance: 41 уникальных значений
# Parental_Involvement: 3 уникальных значений
# Access_to_Resources: 3 уникальных значений
# Extracurricular_Activities: 2 уникальных значений
# Sleep_Hours: 7 уникальных значений
# Previous_Scores: 51 уникальных значений
# Motivation_Level: 3 уникальных значений
# Internet_Access: 2 уникальных значений
# Tutoring_Sessions: 9 уникальных значений
# Family_Income: 3 уникальных значений
# Teacher_Quality: 3 уникальных значений
# School_Type: 2 уникальных значений
# Peer_Influence: 3 уникальных значений
# Physical_Activity: 7 уникальных значений
# Learning_Disabilities: 2 уникальных значений
# Parental_Education_Level: 3 уникальных значений
# Distance_from_Home: 3 уникальных значений
# Gender: 2 уникальных значений
# Exam_Score: 45 уникальных значений

# %% [markdown]
# ⏰ задача
#
# Определить типы переменных
#
# номинальные переменные (не имеют порядка и сравнения)
# порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему
#
# Если одна переменная подходит под несколько типов
#
# Переменные studytime (1–4) и failures (0–4) лучше трактовать как категории с порядком (1 = мало, 4 = много)а не как непрерывное число. Переменные G1, G2, G3 — это оценки по 20-балльной шкале: их можно считать числовыми, так как арифметические операции (среднее, дисперсия) имеют смысл.

# %%
#Номинальные переменные (без порядка)
nominal_vars = [
    "Parental_Involvement", "Access_to_Resources", "Extracurricular_Activities",
    "Internet_Access", "Teacher_Quality", "School_Type", "Peer_Influence",
    "Learning_Disabilities", "Gender"
]

#Порядковые переменные (имеют порядок)
ordinal_vars = [
    "Motivation_Level", "Family_Income", "Parental_Education_Level",
    "Distance_from_Home"
]

#Числовые переменные
numeric_vars = [
    "Hours_Studied", "Attendance", "Sleep_Hours", "Previous_Scores",
    "Tutoring_Sessions", "Physical_Activity", "Exam_Score"
]

# %%
# --- Статистика для числовых переменных ---
print("=== Статистика для числовых переменных ===")
print(df[numeric_vars].describe())

# --- Статистика для категориальных переменных ---
print("\n=== Статистика для номинальных переменных ===")
for col in nominal_vars:
    print(f"\n{col}:")
    print(df[col].value_counts())

print("\n=== Статистика для порядковых переменных ===")
for col in ordinal_vars:
    print(f"\n{col}:")
    print(df[col].value_counts())
# Out:
# === Статистика для числовых переменных ===
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# ## 4. Визуализация распределения переменных

# %% [markdown]
# 1.Гистограмма для числовых переменных:

# %%
sns.histplot(df['Exam_Score'], kde=True)
plt.title('Распределение оценок за экзамен')
plt.xlabel('Exam Score')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# задача ⏰
#
# Описать вывод графиков.
#
#
# Является ли распределение нормальным или отлично от него?
#
# Концентрация большинства значений
# если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
# p.s. 3-5 самых показательных примеров.

# %%
sns.histplot(data=df, x="Exam_Score", hue="Gender", kde=True, element="step")
plt.title("Распределение итоговых оценок по полу")
plt.show()

# %% [markdown]
# Нормальность распределения: Распределение оценок не является нормальным для обоих полов
#
# Концентрация значений: Большинство оценок сконцентрировано в промежутке от 8 до 14 баллов
#
# Различия по полу: Женщины имеют более высокую концентрацию оценок в диапазоне 10-12 баллов, в то время как мужчины показывают более равномерное распределение

# %%
sns.histplot(data=df, x="Attendance", hue="Motivation_Level", kde=False, bins=20)
plt.title("Посещаемость по уровню мотивации")
plt.show()

# %% [markdown]
# Концентрация значений: Большинство значений посещаемости сконцентрировано в диапазоне 80-100%
#
# Влияние мотивации: Студенты с высоким уровнем мотивации демонстрируют значительно более высокую посещаемость
#
# Распределение: Распределение смещено в сторону высоких значений, особенно для высокомотивированных студентов

# %%
sns.histplot(data=df, x="Hours_Studied", hue="Internet_Access", multiple="dodge")
plt.title("Время на учебу в зависимости от доступа к интернету")
plt.show()

# %% [markdown]
# Концентрация значений: Большинство студентов изучают 3-6 часов в неделю
#
# Влияние интернета: Студенты с доступом к интернету тратят в среднем на 1-2 часа больше на учебу
#
# Распределение: Распределение не является нормальным, имеет положительную асимметрию

# %% [markdown]
# ### 2. Столбчатая диаграмма для категориальной переменной Class:

# %%
sns.countplot(x='Motivation_Level', data=df)
plt.title('Распределение уровня мотивации')
plt.xlabel('Уровень мотивации')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# Выводы:
#
# Концентрация значений: Переменная концентрируется в значении "Средний" уровень мотивации
#
# Распределение: Распределение не нормальное, большинство студентов имеют среднюю мотивацию, низкая и высокая мотивация встречаются реже

# %%
sns.countplot(x='Motivation_Level', hue='Gender', data=df)
plt.title('Распределение мотивации по полу')
plt.xlabel('Уровень мотивации')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# Предсказание по полу: У девушек чаще встречаются высокие значения мотивации, у юношей — средние и низкие

# %%
sns.boxplot(x=df['Exam_Score'])
plt.title('Boxplot Exam_Score')
plt.xlabel('Exam_Score')
plt.show()

# %% [markdown]
# Выводы:
#
# Выбросы: Есть выбросы в области низких оценок (0-4 балла)
#
# Медиана: Медиана находится на уровне 10-11 баллов

# %%
sns.boxplot(x="Gender", y="Exam_Score", data=df)
plt.title("Boxplot итоговых оценок по полу")
plt.show()

# %% [markdown]
# Выводы:
#
# Различия по медиане: Медиана у девушек немного выше, чем у юношей
#
# Разброс значений: У юношей больший разброс оценок, экстремально низкие оценки встречаются у обоих полов
#
# Предсказание: По распределению оценок можно предсказать пол студента - более высокие и стабильные оценки характерны для девушек

# %% [markdown]
# ## Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:

# %%
# Корреляционная матрица
correlation_matrix = df_numeric.corr()

# Визуализация тепловой карты
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', center=0)
plt.title('Корреляционная матрица числовых переменных')
plt.tight_layout()
plt.show()

# %% [markdown]
# Интерпретация результатов:
#
# Переменные с сильной положительной корреляцией (≥ 0.7):
# Previous_Scores и Exam_Score - предыдущие оценки сильно связаны с итоговыми результатами
#
# Hours_Studied и Exam_Score - время подготовки напрямую влияет на экзаменационный результат
#
# Переменные со слабой корреляцией (0.3 ≤ corr < 0.7):
# Attendance и Exam_Score - посещаемость умеренно влияет на успеваемость
#
# Sleep_Hours и Exam_Score - продолжительность сна слабо связана с оценками
#
# Переменные без корреляции (|corr| < 0.3):
# Physical_Activity и Exam_Score - физическая активность не влияет на академические результаты
#
# Tutoring_Sessions и Sleep_Hours - занятия с репетитором не связаны с режимом сна
#
# Hours_Studied и Sleep_Hours - время учебы и продолжительность сна независимы
#
# Основной вывод: Самые значимые факторы успеваемости - предыдущая академическая история и время, затраченное на подготовку.
